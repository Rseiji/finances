# %%
import pandas as pd
from sqlalchemy import create_engine
from datetime import datetime
import os

PWD = os.getenv("postgres_pwd")

# Conexão
engine = create_engine(f"postgresql+psycopg2://postgres:{PWD}@localhost:5432/finances")

# # Inserir os dados
# df.to_sql("gastos", engine, if_exists="append", index=False)

# %%
df = pd.read_csv("raw_data/coinext_depositos.csv")

# %%
# Deposits
df2 = df[["PostingDatetime", "CR"]].rename(
    columns={"PostingDatetime": "deposit_date", "CR": "value_brl"}
).assign(
    exchange_name="coinext",
    _processed_at=datetime.now(),
)

df2["deposit_date_2"] = pd.to_datetime(df2["deposit_date"], format="ISO8601").dt.date

df2 = df2.drop(columns="deposit_date").rename(columns={"deposit_date_2": "deposit_date"})

df2 = df2[["deposit_date", "value_brl", "exchange_name", "_processed_at"]]

# df2.to_sql(name="deposits", schema="crypto", con=engine, if_exists="append", index=False)

# %%
# Swaps

swaps = pd.read_csv("/home/ubuntu/finances/raw_data/Sob demanda Ordens incluídas de 2020-04-12 to 2025-04-12.csv")

# %%
swaps = swaps.drop(columns=["RegisteredEntityId", "ClientOrderId", "ExtTradeReportId", "AccountName", "AccountName", "TransReportRevision", "Trader", "AccountId", "TradeId", "QuoteId", "TransReportId", "TransReportType", "OrderId", "MakerTaker", "OMSId", "CounterpartySettlementAmount"])

# %%
# swap_date -> TransReportDatetime
# received_amount -> BaseSettlementAmount
# paid_taxes_amount -> Fee
# paid_amount -> Notional
# received_currency -> Instrument
# paid_taxes_currency -> received_currency
# paid_currency -> Instrument
# exchange_name -> coinext
# _processed_at -> datetime.now()
# swaps = swaps[[
#     "TransReportDatetime",
#     "BaseSettlementAmount",
#     "Fee",
#     "Notional",
#     "Instrument",
# ]]
swaps["received_currency"] = swaps["Instrument"].apply(lambda x: x[:3])
swaps["paid_taxes_currency"] = swaps["received_currency"].copy()
swaps["paid_currency"] = swaps["Instrument"].apply(lambda x: x[3:])

# %%
swaps = swaps.rename(columns={
    "TransReportDatetime": "swap_date",
    "BaseSettlementAmount": "received_amount",
    "Fee": "paid_taxes_amount",
    "Notional": "paid_amount",
}).assign(
    swap_date=pd.to_datetime(swaps["TransReportDatetime"], format="ISO8601").dt.date,
).drop(columns='Instrument').assign(
    exchange_name="coinext", _processed_at=datetime.now()
)

# %%
swaps_buy = swaps[swaps["Side"] == "Buy"]

# %%
swaps_sell = swaps[swaps["Side"] == "Sell"]

# %%
# Replace DOG to DOGE
swaps_buy["paid_taxes_currency"] = swaps_buy["paid_taxes_currency"].replace("DOG", "DOGE")
swaps_buy["paid_taxes_currency"] = swaps_buy["paid_taxes_currency"].replace("LIN", "LINK")

swaps_buy["received_currency"] = swaps_buy["received_currency"].replace("DOG", "DOGE")
swaps_buy["received_currency"] = swaps_buy["received_currency"].replace("LIN", "LINK")

swaps_buy["paid_currency"] = swaps_buy["paid_currency"].replace("EBRL", "BRL")
swaps_buy["paid_currency"] = swaps_buy["paid_currency"].replace("KBRL", "BRL")

swaps_buy = swaps_buy[[
    "swap_date",
    "received_amount",
    "paid_taxes_amount",
    "paid_amount",
    "received_currency",
    "paid_taxes_currency",
    "paid_currency",
    "exchange_name",
    "_processed_at",
]]
# Out:
# /tmp/ipykernel_30412/337545932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swaps_buy["paid_taxes_currency"] = swaps_buy["paid_taxes_currency"].replace("DOG", "DOGE")
# /tmp/ipykernel_30412/337545932.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swaps_buy["paid_taxes_currency"] = swaps_buy["paid_taxes_currency"].replace("LIN", "LINK")
# /tmp/ipykernel_30412/337545932.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swaps_buy["received_currency"] = swaps_buy["received_currency"].replace("DOG", "DOGE")
# /tmp/ipykernel_30412/337545932.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swaps_buy["received_currency"] = swaps_buy["received_currency"].replace("LIN", "LINK")
# /tmp/ipykernel_30412/337545932.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swaps_buy["paid_currency"] = swaps_buy["paid_currency"].replace("EBRL", "BRL")
# /tmp/ipykernel_30412/337545932.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swaps_buy["paid_currency"] = swaps_buy["paid_currency"].replace("KBRL", "BRL")

# %%
swaps_sell = swaps_sell[[
    "swap_date",
    "received_amount",
    "paid_taxes_amount",
    "paid_amount",
    "received_currency",
    "paid_taxes_currency",
    "paid_currency",
    "exchange_name",
    "_processed_at",
]]
swaps_sell["received_amount"] *= -1
swaps_sell["received_currency"] = "BRL"
swaps_sell["paid_taxes_currency"] = "BRL"
swaps_sell["paid_currency"] = "DOGE"

# %%
swaps = pd.concat([swaps_buy, swaps_sell])

# %%
swaps
# Out:
#      swap_date  received_amount  paid_taxes_amount  paid_amount  \
# 0   2021-05-16         7.980000       0.000000e+00    99.976632
# 1   2021-05-24        23.382500       1.175000e-01    40.047995
# 2   2021-05-24         5.771000       2.900000e-02     9.917826
# 3   2021-05-24         0.004179       2.100000e-05    50.043168
# 5   2021-06-03         0.756200       3.800000e-03     7.045124
# 6   2021-06-03         5.860550       2.945000e-02    54.600300
# 7   2021-08-21         7.471275       1.872500e-02   100.366000
# 8   2021-08-21         0.009975       2.500000e-05     0.134000
# 9   2021-08-24         0.000382       9.570000e-07    99.541000
# 10  2021-08-28         0.000060       2.990000e-07    15.360580
# 11  2021-09-06         0.000184       9.230000e-07    49.999400
# 12  2021-09-06         0.002388       1.200000e-05    50.064768
# 13  2021-09-06         0.117100       0.000000e+00    51.836657
# 14  2021-09-07         0.000189       4.730000e-07    50.085000
# 15  2021-09-25         2.487500       1.250000e-02    31.147500
# 16  2021-09-25         0.000010       5.000000e-08     2.285800
# 17  2021-10-02         0.000387       1.946000e-06   100.003840
# 18  2021-10-02         0.001692       8.500000e-06    30.005000
# 19  2021-10-02         0.034300       0.000000e+00    20.923000
# 20  2021-10-02         0.798000       2.000000e-03     9.360000
# 21  2021-10-02         3.391500       8.500000e-03    39.780000
# 22  2021-10-12         0.000331       8.300000e-07   105.221910
# 23  2021-10-16         0.007125       1.785800e-05   150.004429
# 24  2021-10-17         0.000474       1.187000e-06   154.784800
# 25  2021-10-20         0.001998       5.009000e-06    46.179983
# 26  2021-10-20         0.002989       7.491000e-06    69.070016
# 27  2021-10-20         0.002992       7.500000e-06    68.700000
# 28  2021-10-21         0.004309       1.080000e-05   100.008000
# 29  2021-10-21         0.000299       7.500000e-07   105.900000
# 30  2021-10-25         0.000284       7.130000e-07   100.605000
# 31  2021-10-25         0.004279       2.150000e-05   101.861152
# 32  2021-10-25         0.219450       5.500000e-04    39.160000
# 33  2021-10-25         0.379050       9.500000e-04    67.640000
# 34  2021-10-25         0.004279       2.150000e-05   101.694914
# 35  2021-10-27         0.000298       1.500000e-06   102.296829
# 36  2021-10-27         0.006965       3.500000e-05   158.200000
# 37  2021-10-27         0.000448       2.250000e-06   149.044995
# 38  2021-10-27         0.400000       0.000000e+00    56.320000
# 39  2021-10-27         4.975000       2.500000e-02    55.950000
# 40  2021-10-27         0.003482       1.750000e-05    79.099965
# 41  2021-10-27         0.006513       1.632300e-05   146.908350
# 42  2021-10-27         0.000320       8.020000e-07     7.216650
# 43  2021-11-01         0.000143       7.190000e-07    49.923551
# 44  2021-11-01         0.002045       5.125000e-06    50.225000
# 45  2021-12-01         0.000298       1.500000e-06    98.655819
# 46  2021-12-01         5.486250       1.375000e-02    49.500000
# 47  2021-12-04         0.000199       5.000000e-07    54.000000
# 4   2021-06-03        29.100000       3.099150e-01    61.983000
#
#    received_currency paid_taxes_currency paid_currency exchange_name  \
# 0                ADA                 ADA           BRL       coinext
# 1               DOGE                DOGE           BRL       coinext
# 2               DOGE                DOGE           BRL       coinext
# 3                ETH                 ETH           BRL       coinext
# 5                ADA                 ADA           BRL       coinext
# 6                ADA                 ADA           BRL       coinext
# 7                ADA                 ADA           BRL       coinext
# 8                ADA                 ADA           BRL       coinext
# 9                BTC                 BTC           BRL       coinext
# 10               BTC                 BTC           BRL       coinext
# 11               BTC                 BTC           BRL       coinext
# 12               ETH                 ETH           BRL       coinext
# 13               AXS                 AXS           BRL       coinext
# 14               BTC                 BTC           BRL       coinext
# 15               ADA                 ADA           BRL       coinext
# 16               BTC                 BTC           BRL       coinext
# 17               BTC                 BTC           BRL       coinext
# 18               ETH                 ETH           BRL       coinext
# 19               AXS                 AXS           BRL       coinext
# 20               ADA                 ADA           BRL       coinext
# 21               ADA                 ADA           BRL       coinext
# 22               BTC                 BTC           BRL       coinext
# 23               ETH                 ETH           BRL       coinext
# 24               BTC                 BTC           BRL       coinext
# 25               ETH                 ETH           BRL       coinext
# 26               ETH                 ETH           BRL       coinext
# 27               ETH                 ETH           BRL       coinext
# 28               ETH                 ETH           BRL       coinext
# 29               BTC                 BTC           BRL       coinext
